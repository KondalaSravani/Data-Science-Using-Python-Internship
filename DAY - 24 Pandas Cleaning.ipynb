# %% [markdown]
# ### CONTENTS
#
# - Filtering Data
# - Sorting DataFrame
# - Data Cleaning
# - Matplotlib Introduction
# - Types of plots

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv")
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.shape
# Out:
# (12, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   s.no         12 non-null     int64
#  1   day          12 non-null     object
#  2   temparature  8 non-null      float64
#  3   winspeed     9 non-null      float64
#  4   event        9 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
df.describe()
# Out:
#             s.no  temparature   winspeed
# count  12.000000     8.000000   9.000000
# mean    5.583333    59.000000  13.444444
# std     3.476109    22.940918   3.503966
# min     1.000000    30.000000   9.000000
# 25%     2.750000    40.750000  11.000000
# 50%     5.500000    60.000000  13.000000
# 75%     8.250000    71.750000  15.000000
# max    11.000000    90.000000  20.000000

# %%
df.isna().sum()
# Out:
# s.no           0
# day            0
# temparature    4
# winspeed       3
# event          3
# dtype: int64

# %%
df.tail()
# Out:
#     s.no        day  temparature  winspeed    event
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df['day']
# Out:
# 0      1/2/2019
# 1      1/2/2019
# 2      1/3/2019
# 3      1/4/2019
# 4      1/5/2019
# 5      1/6/2019
# 6      1/7/2019
# 7      1/8/2019
# 8      1/9/2019
# 9     1/10/2019
# 10    1/11/2019
# 11    1/12/2019
# Name: day, dtype: object

# %%
df['temparature']
# Out:
# 0     30.0
# 1      NaN
# 2     43.0
# 3     55.0
# 4     66.0
# 5     34.0
# 6      NaN
# 7     89.0
# 8      NaN
# 9     90.0
# 10    65.0
# 11     NaN
# Name: temparature, dtype: float64

# %%
df['temparature'].count()
# Out:
# 8

# %%
# element count in a column
df['temparature'].value_counts()
# Out:
# 65.0    1
# 90.0    1
# 89.0    1
# 34.0    1
# 66.0    1
# 55.0    1
# 43.0    1
# 30.0    1
# Name: temparature, dtype: int64

# %% [markdown]
# ### Filtering data
#
# - Accessing a particular data or information from given dataframe

# %%
df.head()
# Out:
#    s.no       day  temparature  winspeed    event
# 0     1  1/2/2019         30.0      12.0     rain
# 1     1  1/2/2019          NaN      14.0      NaN
# 2     2  1/3/2019         43.0      13.0     rain
# 3     3  1/4/2019         55.0       NaN  fullair
# 4     4  1/5/2019         66.0      10.0      NaN

# %%
df[df['temparature']>55]
# Out:
#     s.no        day  temparature  winspeed event
# 4      4   1/5/2019         66.0      10.0   NaN
# 7      7   1/8/2019         89.0       NaN  cold
# 9      9  1/10/2019         90.0      11.0  cold
# 10    10  1/11/2019         65.0       NaN   NaN

# %%
# filter winspeed greater than 13
df[df['winspeed']>13]
# Out:
#     s.no        day  temparature  winspeed    event
# 1      1   1/2/2019          NaN      14.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
# filter the data temp >= 30 and winspeed ==15
df[(df['temparature']>=30) & (df['winspeed']==15)]
# Out:
#    s.no       day  temparature  winspeed event
# 5     5  1/6/2019         34.0      15.0  cold

# %%
# filter the data temp >40 or winspeed ==15
df[(df['temparature']>40) | (df['winspeed']==15)]
# Out:
#     s.no        day  temparature  winspeed    event
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN

# %% [markdown]
# ### Sorting DataFrames
# - sort_index
#     - to sort index
#
# - sort_values
#     - to sort values
#
# - 2 Types:
#     - Ascending order
#     - Descending order

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature")
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 4      4   1/5/2019         66.0      10.0      NaN
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 8      8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature",ascending=True)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 4      4   1/5/2019         66.0      10.0      NaN
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 8      8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature",ascending=True,ignore_index=True)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4     10  1/11/2019         65.0       NaN      NaN
# 5      4   1/5/2019         66.0      10.0      NaN
# 6      7   1/8/2019         89.0       NaN     cold
# 7      9  1/10/2019         90.0      11.0     cold
# 8      1   1/2/2019          NaN      14.0      NaN
# 9      6   1/7/2019          NaN      17.0  fullair
# 10     8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
s1=df.sort_values("winspeed")
s1
# Out:
#     s.no        day  temparature  winspeed    event
# 8      8   1/9/2019          NaN       9.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 9      9  1/10/2019         90.0      11.0     cold
# 0      1   1/2/2019         30.0      12.0     rain
# 2      2   1/3/2019         43.0      13.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair
# 3      3   1/4/2019         55.0       NaN  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 10    10  1/11/2019         65.0       NaN      NaN

# %%
s1.sort_index()
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
# to get index in descending order
s1.sort_index(ascending=False)
# Out:
#     s.no        day  temparature  winspeed    event
# 11    11  1/12/2019          NaN      20.0  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 9      9  1/10/2019         90.0      11.0     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 5      5   1/6/2019         34.0      15.0     cold
# 4      4   1/5/2019         66.0      10.0      NaN
# 3      3   1/4/2019         55.0       NaN  fullair
# 2      2   1/3/2019         43.0      13.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 0      1   1/2/2019         30.0      12.0     rain

# %%
df.sort_values(["temparature","winspeed"])
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 4      4   1/5/2019         66.0      10.0      NaN
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %% [markdown]
# ### Cleaning the DataFrame
#
# - to check unwanted data/missing data
#     - isnull()
#     - notnull()
# - to remove unwanted data
#      - dropna()
# - Handling unwanted data
#      - fillna()
#      - replace()

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %% [markdown]
# #### Preprocessing
#
# - Checking nullvalues
# - remove null values
# - fill null values

# %%
df.isnull()
# Out:
#      s.no    day  temparature  winspeed  event
# 0   False  False        False     False  False
# 1   False  False         True     False   True
# 2   False  False        False     False  False
# 3   False  False        False      True  False
# 4   False  False        False     False   True
# 5   False  False        False     False  False
# 6   False  False         True     False  False
# 7   False  False        False      True  False
# 8   False  False         True     False  False
# 9   False  False        False     False  False
# 10  False  False        False      True   True
# 11  False  False         True     False  False

# %%
# to count null values
df.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    4
# winspeed       3
# event          3
# dtype: int64

# %%
# to remove null values
d1 = df.dropna()
d1
# Out:
#    s.no        day  temparature  winspeed event
# 0     1   1/2/2019         30.0      12.0  rain
# 2     2   1/3/2019         43.0      13.0  rain
# 5     5   1/6/2019         34.0      15.0  cold
# 9     9  1/10/2019         90.0      11.0  cold

# %%
d1.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    0
# winspeed       0
# event          0
# dtype: int64

# %%
# not the null values
d1.notnull().sum()
# Out:
# s.no           4
# day            4
# temparature    4
# winspeed       4
# event          4
# dtype: int64

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.fillna(0)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          0.0      14.0        0
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       0.0  fullair
# 4      4   1/5/2019         66.0      10.0        0
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          0.0      17.0  fullair
# 7      7   1/8/2019         89.0       0.0     cold
# 8      8   1/9/2019          0.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       0.0        0
# 11    11  1/12/2019          0.0      20.0  fullair

# %%
# replacing null values in temperature with 1,winspped 2,event as sunny
df.fillna({'temparature':1,'winspeed':2,'event':'sunny'},inplace=True)
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          1.0      14.0    sunny
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       2.0  fullair
# 4      4   1/5/2019         66.0      10.0    sunny
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          1.0      17.0  fullair
# 7      7   1/8/2019         89.0       2.0     cold
# 8      8   1/9/2019          1.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       2.0    sunny
# 11    11  1/12/2019          1.0      20.0  fullair

# %%
df.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    0
# winspeed       0
# event          0
# dtype: int64

# %%
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          1.0      14.0    sunny
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       2.0  fullair
# 4      4   1/5/2019         66.0      10.0    sunny
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          1.0      17.0  fullair
# 7      7   1/8/2019         89.0       2.0     cold
# 8      8   1/9/2019          1.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       2.0    sunny
# 11    11  1/12/2019          1.0      20.0  fullair

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv")
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df1['temparature'].mean()
# Out:
# 59.0

# %%
# fill temperature with mean of temperature
df1['temparature'] = df1['temparature'].fillna(df1['temparature'].mean())
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1['winspeed'].median()
# Out:
# 13.0

# %%
# fill winspeed with median of winspeed
df1['winspeed'] = df1['winspeed'].fillna(df1['winspeed'].median())
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
# limit 2 positions
df1.fillna(11,limit=2)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0       11
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0       11
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.fillna(method='ffill')
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0     rain
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0  fullair
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0     cold
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
import numpy as np
df1['temparature'][0]
# Out:
# 30.0

# %%
df1['temparature'][0]=np.nan
# Out:
# <ipython-input-96-2a2bae935125>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['temparature'][0]=np.nan

# %%
df1['temparature'][0]
# Out:
# nan

# %%
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %% [markdown]
# ##### REPLACE

# %%
df1.head()
# Out:
#    s.no       day  temparature  winspeed    event
# 0     1  1/2/2019          NaN      12.0     rain
# 1     1  1/2/2019         59.0      14.0      NaN
# 2     2  1/3/2019         43.0      13.0     rain
# 3     3  1/4/2019         55.0      13.0  fullair
# 4     4  1/5/2019         66.0      10.0      NaN

# %%
df1.replace('rain','sunny')
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0    sunny
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0    sunny
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.replace(20,25)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      25.0  fullair

# %%
df1.replace('NaN',1)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.columns
# Out:
# Index(['s.no', 'day', 'temparature', 'winspeed', 'event'], dtype='object')

# %%
df1['n1'] = np.random.randint(1,12,12)
df1
# Out:
#     s.no        day  temparature  winspeed    event  n1
# 0      1   1/2/2019          NaN      12.0     rain   3
# 1      1   1/2/2019         59.0      14.0      NaN   6
# 2      2   1/3/2019         43.0      13.0     rain  10
# 3      3   1/4/2019         55.0      13.0  fullair   3
# 4      4   1/5/2019         66.0      10.0      NaN   3
# 5      5   1/6/2019         34.0      15.0     cold  11
# 6      6   1/7/2019         59.0      17.0  fullair   3
# 7      7   1/8/2019         89.0      13.0     cold   4
# 8      8   1/9/2019         59.0       9.0  fullair   2
# 9      9  1/10/2019         90.0      11.0     cold   7
# 10    10  1/11/2019         65.0      13.0      NaN   1
# 11    11  1/12/2019         59.0      20.0  fullair   8

# %%
# Remove the column
df1.drop('n1',axis=1)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      13.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      13.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      13.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.columns
# Out:
# Index(['s.no', 'day', 'temparature', 'winspeed', 'event', 'n1'], dtype='object')

# %%
df1.plot()

# %%
df1.plot()
