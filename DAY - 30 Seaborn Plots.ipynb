# %% [markdown]
# ### CONTENTS
#
# - categorical distributed plots
#     - histogram plots
#     - box
#     - kde plots
#     - violin plots
# - categorical distribution plots
#     - bar plot
#     - point plot
#     - count plot
# - join plot
# - pair plot
# - heat map

# %% [markdown]
# ### Box Plot
#
# - IQR range
# - min,median,max
# - It is also called as whisker plot
# - To show distributions w.r.t categories
# - Syntax : seaborn.boxplot

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# C:\Users\sravani\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\sravani\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.boxplot(data=df)

# %%
sns.boxplot(x='age',y='survived',data=df)

# %%
sns.boxplot(x='embarked',y='survived',data=df,hue='sex')

# %%
df1 = sns.load_dataset("tips")
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data=df1)

# %%
import seaborn as sns
#sns.set_theme("notebook")
sns.boxplot(x='tip',y='sex',data=df1,hue="smoker")

# %%
sns.boxplot(x='tip',y='sex',data=df1,hue="smoker",palette="Set2",linewidth=5)

# %%
sns.boxplot(x='tip',y='sex',data=df1,hue="day",palette="Set2",linewidth=5)

# %%
sns.boxplot(data=df1,orient='h')

# %% [markdown]
# ### Kde Plot
#
# - Kernal Density Estimator
# - sns.kdeplot()

# %%
import seaborn as sns

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data=df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-331ab8a7c490> in <module>
# ----> 1 sns.kdeplot(data=df1)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
sns.kdeplot(x="tip",y="total_bill",data=df1,hue='sex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e983413fdb9c> in <module>
# ----> 1 sns.kdeplot(x="tip",y="total_bill",data=df1,hue='sex')
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
sns.kdeplot(x='tip',data=df1,bw_adjust=5,hue='day')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-64637b33e089> in <module>
# ----> 1 sns.kdeplot(x='tip',data=df1,bw_adjust=5,hue='day')
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
sns.kdeplot(x='tip',data=df1,bw_adjust=5,hue='day',multiple='stack')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7f76dd989934> in <module>
# ----> 1 sns.kdeplot(x='tip',data=df1,bw_adjust=5,hue='day',multiple='stack')
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
# ...

# %% [markdown]
# ### violin Plot
#
# - Box Plot + KDE Plot

# %%
import seaborn as sns

# %%
sns.violinplot(data=df1)

# %%
sns.violinplot(x=df1['tip'],data=df1)

# %%
sns.violinplot(x=df1['day'],y=df1['size'],data=df1)

# %%
sns.violinplot(x=df1['day'],y=df1['size'],data=df1,hue='sex')

# %%
sns.violinplot(x=df1['day'],y=df1['size'],data=df1,palette='Oranges')

# %%
sns.violinplot(x=df1['day'],y=df1['size'],data=df1,palette='Oranges',split=True,hue='sex')

# %%
sns.violinplot(x=df1['day'],y=df1['size'],data=df1,hue='sex',palette='Oranges',split=True,inner='quartile')

# %% [markdown]
# ### categorical distribution plots
# - bar plot
# - point plot
# - count plot

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(data=df1)

# %%
sns.barplot(x='day',y='tip',data=df1,hue='smoker')

# %%
import numpy as np
sns.barplot(x='day',y='tip',data=df1,estimator=np.mean)

# %%
sns.barplot(x='day',y='tip',data=df1,estimator=np.std)# estimator takes only numeric data

# %%
df1['tip'].std()
# Out:
# 1.3836381890011826

# %% [markdown]
# ### Point Plot

# %%
sns.pointplot(data=df1)

# %%
sns.pointplot(x='day',y='tip',data=df1,estimator=np.mean)

# %%
sns.pointplot(x='sex',y='total_bill',data=df1,estimator=np.mean)

# %%
sns.pointplot(x='sex',y='total_bill',data=df1,hue='day',estimator=np.mean)

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='sex',y='total_bill',data=df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-1437547c44e0> in <module>
# ----> 1 sns.jointplot(x='sex',y='total_bill',data=df1)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2291         marginal_kws.setdefault("kde", False)
#    2292         marginal_kws.setdefault("color", color)
# -> 2293         grid.plot_marginals(distplot, **marginal_kws)
#    2294
#    2295     elif kind.startswith("hex"):
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1800         kwargs["vertical"] = False
#    1801         plt.sca(self.ax_marg_x)
# -> 1802         func(self.x, **kwargs)
#    1803
#    1804         kwargs["vertical"] = True
#
# ...

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(data=df1)

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
